# %%
import pennylane as qml
import matplotlib.pyplot as plt
import numpy as np
from tools import *
import sys
import pickle
import os

# %%
def read(file_name):
    with open(file_name, 'rb') as f:
        mynewlist = pickle.load(f)
    return mynewlist

# %%
files =['Fidelidades_nqb-1.pkl', 'Fidelidades_nqb-2.pkl', 'Fidelidades_nqb-3.pkl', 'Fidelidades_nqb-4.pkl']

with open(files[3], 'rb') as f:
    mynewlist = pickle.load(f)
len(mynewlist)
# Out:
# 14

# %%
with open(files[0], 'rb') as f:
    y1 = pickle.load(f)
with open(files[1], 'rb') as f:
    y2 = pickle.load(f)
with open(files[2], 'rb') as f:
    y3 = pickle.load(f)
with open(files[3], 'rb') as f:
    y4 = pickle.load(f)

# %%
size = 14
x = np.linspace(1, size, size)
plt.plot(x, y1[0:size], label='1 Qubit')
plt.plot(x, y2[0:size], label='2 Qubit', linestyle=":")
plt.plot(x, y3[0:size], label='3 Qubit', linestyle="--")
plt.plot(x, y4[0:size], label='4 Qubit', linestyle="dashdot")
plt.title('Fidelidade dos estados preparados')
plt.ylim(0.97, 1.01)
plt.legend()
plt.show()
