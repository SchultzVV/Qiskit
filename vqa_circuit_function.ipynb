# %%
#from sympy import conjugate
from torch.autograd import Variable
import torch
from rsvg import rsvg
import pennylane as qml
import matplotlib.pyplot as plt
import numpy as np
from tools import *

# %%
n_qubits = 3
circuit, params = vqa(n_qubits)
target_vector, alpha = init_state_rsvg(n_qubits)
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %%
def vqa(n_qubits):
    #n_qubits = 1
    depht = n_qubits+1
    n = 3*n_qubits*(1+depht)
    params = random_params(n)
    device = get_device(n_qubits)
    @qml.qnode(device, interface="torch")
    def circuit(params, M=None):
        w = []
        aux = 0
        for j in range(n_qubits):
            qml.RX(params[j+aux], wires=j)
            qml.RY(params[j+1+aux], wires=j)
            qml.RZ(params[j+2+aux], wires=j)
            w.append(j)
            aux+=2
        if n_qubits == 1:
            for z in range(1,depht):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                aux+=2
            return qml.expval(qml.Hermitian(M, wires=w))
        for z in range(depht):
            for i in range(n_qubits-1):
                qml.CNOT(wires=[i,i+1])
            for j in range(n_qubits):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                aux+=2
        return qml.expval(qml.Hermitian(M, wires=w))
    return circuit, params
n_qubits = 3
circuit, params = vqa(n_qubits)
target_vector, alpha = init_state_rsvg(n_qubits)
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %% [markdown]
# # Escolha o número de qubits
# * n_qubits é o número de qubits do estado a ser preparado

# %%
best_params, f = train(2, circuit, params, alpha)
# Out:
# 1 0.002384185791015636

# %%
best_params, f = train(2, circuit, params, alpha)
# Out:
# 1 0.002289772033691417

# %%
import sys
class VQA():
    def __init__(self, n_qubits):#, target_vector, params, device):
        self.n_qubits = n_qubits
        self.depht = n_qubits+1
        self.n = 3*n_qubits*(1+depht)
        self.target_vector, _ = init_state_rsvg(n_qubits)
        self.params = random_params(n)
        self.device = get_device(n_qubits)
        self.target_vector = target_vector
        print(f'n_qubits = {n_qubits}')
        print(f'depth = {depht}')
        print(f'sizeof(params) =  {sys.getsizeof(params)/1000} kbytes ')
        print(f'sizeof(target_vector) = {sys.getsizeof(target_vector)/1000} kbytes ')
    
    #device = get_device(n_qubits)
    @qml.qnode(device, interface="torch")
    def circuit(params, M=None):
            w = []
            aux = 0
            for j in range(n_qubits):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                w.append(j)
                aux+=2
            if n_qubits == 1:
                for z in range(1,depht):
                    qml.RX(params[j+aux], wires=j)
                    qml.RY(params[j+1+aux], wires=j)
                    qml.RZ(params[j+2+aux], wires=j)
                    aux+=2
                return qml.expval(qml.Hermitian(M, wires=w))
            for z in range(depht):
                for i in range(n_qubits-1):
                    qml.CNOT(wires=[i,i+1])
                for j in range(n_qubits):
                    qml.RX(params[j+aux], wires=j)
                    qml.RY(params[j+1+aux], wires=j)
                    qml.RZ(params[j+2+aux], wires=j)
                    aux+=2
            return qml.expval(qml.Hermitian(M, wires=w))

n_qubits = 1
depht = n_qubits+1
n = 3*n_qubits*(1+depht)
target_vector, alpha = init_state_rsvg(n_qubits)
params = random_params(n)
device = get_device(n_qubits)
model = VQA(n_qubits)#, target_vector, params, device)
circuit = model.circuit
print(circuit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19618/26166217.py in <module>
#       1 import sys
# ----> 2 class VQA():
#       3     def __init__(self, n_qubits):#, target_vector, params, device):
#       4         self.n_qubits = n_qubits
#       5         self.depht = n_qubits+1
#
# /tmp/ipykernel_19618/26166217.py in VQA()
#      15
#      16     #device = get_device(n_qubits)
# ---> 17     @qml.qnode(device, interface="torch")
#      18     def circuit(params, M=None):
#      19             w = []
#
# NameError: name 'device' is not defined

# %%
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19618/2902283459.py in <module>
# ----> 1 fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
#       2 plt.show()
#
# ~/anaconda3/lib/python3.9/site-packages/pennylane/drawer/draw.py in wrapper(*args, **kwargs_qnode)
#     438         try:
#     439             qnode.expansion_strategy = expansion_strategy or original_expansion_strategy
# --> 440             qnode.construct(args, kwargs_qnode)
#     441         finally:
#     442             qnode.expansion_strategy = original_expansion_strategy
#
# ~/anaconda3/lib/python3.9/site-packages/pennylane/qnode.py in construct(self, args, kwargs)
#     526
#     527         with self.tape:
# --> 528             self._qfunc_output = self.func(*args, **kwargs)
#     529         self._tape._qfunc_output = self._qfunc_output
#     530
#
# /tmp/ipykernel_19618/1981229340.py in circuit(params, M)
#      22                 qml.RZ(params[j+2+aux], wires=j)
#      23                 aux+=2
# ---> 24             return qml.expval(qml.Hermitian(M, wires=w))
#      25         for z in range(depht):
#      26             for i in range(n_qubits-1):
#
# ~/anaconda3/lib/python3.9/site-packages/pennylane/ops/qubit/observables.py in __init__(self, A, wires, do_queue, id)
#      80                 expected_mx_shape = self._num_basis_states
#      81
# ---> 82             Hermitian._validate_input(A, expected_mx_shape)
#      83
#      84         super().__init__(A, wires=wires, do_queue=do_queue, id=id)
#
# ~/anaconda3/lib/python3.9/site-packages/pennylane/ops/qubit/observables.py in _validate_input(A, expected_mx_shape)
#      91
#      92         if expected_mx_shape is not None and A.shape[0] != expected_mx_shape:
# ---> 93             raise ValueError(
#      94                 f"Expected input matrix to have shape {expected_mx_shape}x{expected_mx_shape}, but "
#      95                 f"a matrix with shape {A.shape[0]}x{A.shape[0]} was passed."
#
# ValueError: Expected input matrix to have shape 2x2, but a matrix with shape 4x4 was passed.

# %%
import sys
class VQA():
    def __init__(self, n_qubits):#, target_vector, params, device):
        self.n_qubits = n_qubits
        self.depht = n_qubits+1
        n = 3*n_qubits*(1+depht)
        target_vector, _ = init_state_rsvg(n_qubits)
        params = random_params(n)
        device = get_device(n_qubits)
        self.target_vector = target_vector
        self.params = params
        self.device = device
        print(f'n_qubits = {n_qubits}')
        print(f'depth = {depht}')
        print(f'sizeof(params) =  {sys.getsizeof(params)/1000} kbytes ')
        print(f'sizeof(target_vector) = {sys.getsizeof(target_vector)/1000} kbytes ')
    
    @qml.qnode(device, interface="torch")
    def circuit(params, M=None):
        w = []
        aux = 0
        for j in range(n_qubits):
            qml.RX(params[j+aux], wires=j)
            qml.RY(params[j+1+aux], wires=j)
            qml.RZ(params[j+2+aux], wires=j)
            w.append(j)
            aux+=2
        if n_qubits == 1:
            for z in range(1,depht):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                aux+=2
            return qml.expval(qml.Hermitian(M, wires=w))
        for z in range(depht):
            for i in range(n_qubits-1):
                qml.CNOT(wires=[i,i+1])
            for j in range(n_qubits):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                aux+=2
        return qml.expval(qml.Hermitian(M, wires=w))

n_qubits = 1
depht = n_qubits+1
n = 3*n_qubits*(1+depht)
target_vector, alpha = init_state_rsvg(n_qubits)
params = random_params(n)
device = get_device(n_qubits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19060/1479770304.py in <module>
#       1 import sys
# ----> 2 class VQA():
#       3     def __init__(self, n_qubits):#, target_vector, params, device):
#       4         self.n_qubits = n_qubits
#       5         self.depht = n_qubits+1
#
# /tmp/ipykernel_19060/1479770304.py in VQA()
#      16         print(f'sizeof(target_vector) = {sys.getsizeof(target_vector)/1000} kbytes ')
#      17
# ---> 18     @qml.qnode(device, interface="torch")
#      19     def circuit(params, M=None):
#      20         w = []
#
# NameError: name 'device' is not defined

# %%
model = VQA(n_qubits)#, target_vector, params, device)
circuit = model.circuit
#model.circuit(params)
#print(circuit)
# Out:
# n_qubits = 1
# depth = 2
# sizeof(params) =  0.072 kbytes
# sizeof(target_vector) = 0.136 kbytes

# %%
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %%
x_list1 = [2, 2, 4, 5, 25]
x_list2 = [2, 2, 2, 2, 25]
x1 = 7.6
x2 = 25.6
print(variancia(x_list1,x1))
print(variancia(x_list1,x2))
# Out:
# (0.0, 7.6)
# (324.0, 7.6)
