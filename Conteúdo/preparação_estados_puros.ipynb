# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
from sympy import conjugate
from qiskit_textbook.widgets import plot_bloch_vector_spherical
from torch.autograd import Variable
import torch
from tools import *

# %% [markdown]
# # Circuito quantico variacional
#
#     Um circuito quantico variacional é descrito por:
#
# $$f = \langle\psi_0|U^\dagger(\theta)M U(\theta)|\psi_0\rangle
# $$
# $$ f = \langle\psi_1|M|\psi_1\rangle
# $$
#
# Seja o estado $|\phi\rangle$ o estado que queremos preparar, para isso definimos uma medida M, que é o estado desejado.
# $$M = |\phi\rangle\langle\phi|$$
#
# Buscamos uma função que maximize a fidelidade entre $|\psi\rangle$ e $|\phi\rangle$
# Podemos obter a fidelidade de maneira direta com essa medida.
#
# $$f = \langle\psi_1|M|\psi_1\rangle$$
# $$f = \langle\psi_1|\psi\rangle\langle\phi|\psi_1\rangle = F(|\psi_1\rangle, |\phi\rangle)$$
#
# O valor esperado do circuito será a fidelidade.

# %%
from rdmg import rdm_ginibre
target_rho = rdm_ginibre(2)
print(target_rho)
# Out:
# [[0.79313712+0.j         0.09423007-0.14573284j]
#  [0.09423007+0.14573284j 0.20686288+0.j        ]]

# %%
# gerando os estados aleatórios
c0 = np.random.rand()**0.5
c1 = (1.0 - c0**2)**0.5
target_state = np.array([[c0],[c1]])
target_op = np.outer(target_state.conj(), target_state)
theta = 2*np.arccos(c0)
target_expectedValue = np.cos(theta)

print(target_state)
print(target_op)
print(target_expectedValue)
# Out:
# [[0.7221181]
#  [0.6917698]]
# [[0.52145455 0.49953949]
#  [0.49953949 0.47854545]]
# 0.04290909788300398

# %% [markdown]
# # Plotando o estado que queremos preparar

# %%
phi = 0
coords = [theta, phi, 1]
plot_bloch_vector_spherical(coords)

# %% [markdown]
# # Definindo os parâmetros que serão otimizados

# %%
# Qiskit
params = np.random.normal(0, np.pi/2, (2), requires_grad=True)
qc = QuantumCircuit(1)
qc.rx(params[0].item(),0)
qc.ry(params[1].item(),0)
bloch_sphere(qc)

# %%
# Pennylane
device = qml.device('qiskit.aer', wires=1, backend='qasm_simulator')
@qml.qnode(device, diff_method='parameter-shift')
def circuit(params):
    qml.RX(params[0], wires=0)
    qml.RY(params[1], wires=0)
    return qml.expval(qml.PauliZ(0))
qc = circuit(params)

# %% [markdown]
# # Treinando os parâmetros

# %%
def loss(params):
    L = abs(target_expectedValue - circuit(params))
    return L
opt = qml.AdamOptimizer(stepsize=0.01)

for i in range(25):
    print(loss(params), circuit(params), target_expectedValue)
    params = opt.step(loss, params)
# Out:
# 0.4859731654004703 0.146484375 0.6715200404004703
# 0.4625356654004703 0.173828125 0.6715200404004703
# 0.4937856654004703 0.1796875 0.6715200404004703
# 0.4801137904004703 0.212890625 0.6715200404004703
# 0.4430044154004703 0.2578125 0.6715200404004703
# 0.4625356654004703 0.240234375 0.6715200404004703
# 0.4781606654004703 0.228515625 0.6715200404004703
# 0.3453481654004703 0.28515625 0.6715200404004703
# 0.3824575404004703 0.232421875 0.6715200404004703
# 0.4039419154004703 0.37109375 0.6715200404004703
# 0.3629262904004703 0.302734375 0.6715200404004703
# 0.3551137904004703 0.3046875 0.6715200404004703
# 0.3160512904004703 0.271484375 0.6715200404004703
# 0.3668325404004703 0.291015625 0.6715200404004703
# 0.3277700404004703 0.3125 0.6715200404004703
# 0.2848012904004703 0.298828125 0.6715200404004703
# 0.3375356654004703 0.326171875 0.6715200404004703
# 0.2984731654004703 0.359375 0.6715200404004703
# 0.3043325404004703 0.388671875 0.6715200404004703
# 0.2535512904004703 0.33984375 0.6715200404004703
# 0.2359731654004703 0.39453125 0.6715200404004703
# 0.2730825404004703 0.373046875 0.6715200404004703
# 0.2926137904004703 0.38671875 0.6715200404004703
# 0.2984731654004703 0.38671875 0.6715200404004703
# 0.2887075404004703 0.443359375 0.6715200404004703

# %% [markdown]
# # Obtendo o estado usando tomografia de estados no circuito

# %%
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit import Aer
import qiskit
from qiskit import QuantumRegister

qr = QuantumRegister(1)
qc = QuantumCircuit(qr)
qc.rx(params[0].item(), 0)
qc.ry(params[1].item(), 0)

qstc = state_tomography_circuits(qc, qr[0])
nshots = 8192
job = qiskit.execute(qstc, Aer.get_backend('qasm_simulator'), shots=nshots)
qstf = StateTomographyFitter(job.result(), qstc)
rho = qstf.fit(method='lstsq')
print(rho)
# Out:
# [[ 0.71403487+0.j         -0.24492275-0.37973928j]
#  [-0.24492275+0.37973928j  0.28596513+0.j        ]]

# %% [markdown]
# ### Fidelidade
#
# * Estados puros $ F(\rho,\sigma) = Tr[\rho\sigma\rho]^{1/2} = Tr[|\phi\rangle\langle\phi|\psi\rangle\langle\psi|\phi\rangle\langle\phi|]^{1/2} = |\langle\psi|\phi\rangle|$.
#
# * Estados que são diagonais numa mesma base (comutativos) $ F(\rho,\sigma) = \sum_i\sqrt{p_iq_i} $

# %%
def fidelity(rho1, rho2):
    result = abs(inner_product(rho1, rho2))
    return result

# %%
print(fidelity(target_state, target_state))

# %%
from qiskit_textbook.widgets import plot_bloch_vector_spherical
theta = 2*np.arccos(c0)
target_expectedValue = np.cos(theta)
phi = 0
coords = [theta, phi, 1]

plot_bloch_vector_spherical(coords)

# %%
def vqa_prep(target_state, device):
    device = qml.device('qiskit.aer', wires=1, backend='qasm_simulator')
    params = np.random.normal(0, np.pi/2, (2), requires_grad=True)
    @qml.qnode(device, diff_method='parameter-shift')
    def circuit(params):
        qml.RX(params[0], wires=0)
        qml.RY(params[1], wires=0)

        return qml.expval(qml.PauliZ(0))

# %%
device = qml.device('qiskit.aer', wires=1, backend='qasm_simulator')

params = np.random.normal(0, np.pi/2, (2), requires_grad=True)

@qml.qnode(device, diff_method='parameter-shift')

def circuit(params):
    qml.RX(params[0], wires=0)
    qml.RY(params[1], wires=0)

    return qml.expval(qml.PauliZ(0))

fig, ax = qml.draw_mpl(circuit, decimals=2)(params)
plt.show()

# %%
pauli_observables = [
    qml.PauliX(0),
    qml.PauliY(0),
    qml.PauliZ(0)
]

Paulis = Variable(torch.zeros([3, 2, 2], dtype=torch.complex128), requires_grad=False)
Paulis[0] = torch.tensor([[0, 1], [1, 0]])
Paulis[1] = torch.tensor([[0, -1j], [1j, 0]])
Paulis[2] = torch.tensor([[1, 0], [0, -1]])

# %%
purity = 0.5 + 0.5*np.random.rand()
target_vector = np.random.normal(0, 1, 3)
target_vector = target_vector/(np.sum(target_vector**2))
target_vector = target_vector*(2*purity - 1 )**0.5
target_vector = Variable(torch.Tensor(target_vector))
print(target_vector)
print(purity)
# Out:
# tensor([-0.0230, -0.0784, -0.4612])
# 0.7594157662604152

# %%
def cost(params):
    L = 0
    for k in range(3):
        L+= torch.abs(circuit(params, Paulis[k]) - target_vector[k])
    return L

opt = torch.optim.Adam([params], lr=0.1)
best_loss = 1*cost(params)
best_params = 1*params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/v/Desktop/Qiskit/Conteúdo/VQA.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> from torch.autograd import Variable
# ----> <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> Paulis = Variable(torch.zeros([3, 2, 2], dtype=torch.complex128), requires_grad=False)
#
# NameError: name 'torch' is not defined

# %%
X_exp = circuit(params, Paulis[0]).item()
Y_exp = circuit(params, Paulis[1]).item()
Z_exp = circuit(params, Paulis[2]).item()
print(X_exp, Y_exp, Z_exp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/v/Desktop/Qiskit/Conteúdo/VQA.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> X_exp = circuit(params, Paulis[0]).item()
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> Y_exp = circuit(params, Paulis[1]).item()
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> Z_exp = circuit(params, Paulis[2]).item()
#
# File ~/anaconda3/lib/python3.9/site-packages/pennylane/qnode.py:611, in QNode.__call__(self, *args, **kwargs)
#     608         set_shots(self._original_device, override_shots)(self._update_gradient_fn)()
#     610 # construct the tape
# --> 611 self.construct(args, kwargs)
#     613 cache = self.execute_kwargs.get("cache", False)
#     614 using_custom_cache = (
#     615     hasattr(cache, "__getitem__")
#     616     and hasattr(cache, "__setitem__")
#     617     and hasattr(cache, "__delitem__")
#     618 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pennylane/qnode.py:526, in QNode.construct(self, args, kwargs)
#     523 self._tape = qml.tape.QuantumTape()
#     525 with self.tape:
# --> 526     self._qfunc_output = self.func(*args, **kwargs)
#     527 self._tape._qfunc_output = self._qfunc_output
#     529 params = self.tape.get_parameters(trainable_only=False)
#
# TypeError: circuit() takes 1 positional argument but 2 were given

# %%
qc = QuantumCircuit(1,1)
qc.rx(params[0].item(),0)
qc.ry(params[1].item(),0)
bloch_sphere(qc)

# %%
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit.providers.aer import QasmSimulator
import qiskit

qstc = state_tomography_circuits(qc, qc[0])
nshots = 8192
job = qiskit.execute(qstc, Aer.get_backend('qasm_simulator'), shots=nshots)
qstf = StateTomographyFitter(job.result(), qstc)
rho = qstf.fit(method='lstsq')
print(rho)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/v/Desktop/Qiskit/Conteúdo/VQA.ipynb Cell 20 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> from qiskit.providers.aer import QasmSimulator
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> import qiskit
# ----> <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> qstc = state_tomography_circuits(qc, qc[0])
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> nshots = 8192
#       <a href='vscode-notebook-cell:/home/v/Desktop/Qiskit/Conte%C3%BAdo/VQA.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> job = qiskit.execute(qstc, Aer.get_backend('qasm_simulator'), shots=nshots)
#
# File ~/anaconda3/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py:77, in state_tomography_circuits(circuit, measured_qubits, meas_labels, meas_basis)
#      46 def state_tomography_circuits(
#      47         circuit: QuantumCircuit,
#      48         measured_qubits: QuantumRegister,
#      49         meas_labels: Union[str, Tuple[str], List[Tuple[str]]] = 'Pauli',
#      50         meas_basis: Union[str, TomographyBasis] = 'Pauli'
#      51 ) -> List[QuantumCircuit]:
#      52     """
#      53     Return a list of quantum state tomography circuits.
#      54
#    (...)
#      75         experiment use the general function `tomography_circuits`.
#      76     """
# ---> 77     return _tomography_circuits(circuit, measured_qubits, None,
#      78                                 meas_labels=meas_labels, meas_basis=meas_basis,
#      79                                 prep_labels=None, prep_basis=None)
#
# File ~/anaconda3/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py:379, in _tomography_circuits(circuit, measured_qubits, prepared_qubits, meas_labels, meas_basis, prep_labels, prep_basis)
#     377     meas_qubits = _format_registers(*measured_qubits)
#     378 else:
# --> 379     meas_qubits = _format_registers(measured_qubits)
#     380 if isinstance(prepared_qubits, (list, tuple)):
#     381     # Unroll list of registers
#     382     if isinstance(prepared_qubits[0], int):
#
# File ~/anaconda3/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py:649, in _format_registers(*registers)
#     647         qubits.append(tuple_element)
#     648 # Check registers are unique
# --> 649 if len(qubits) != len(set(qubits)):
#     650     raise QiskitError('Qubits to be measured are not unique!')
#     651 return qubits
#
# TypeError: unhashable type: 'CircuitInstruction'

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)
qc.rx(params[0].item(),0)
qc.ry(params[1].item(),0)

from qiskit.visualization import visualize_transition
visualize_transition(qc)
